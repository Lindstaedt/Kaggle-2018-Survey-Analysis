# %% [markdown]
# # Kaggle 2018 Survey Analysis

# %% [markdown]
# ## Overview
# This workbook contains an exploratory data analysis of the Kaggle 2018 Survey data (originally downloaded from https://www.kaggle.com/kaggle/kaggle-survey-2018/)

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pixiedust

# magic word for producing visualizations in notebook
# %matplotlib inline

# magic for pixiedebugger

# magic for autocomplete
# %config IPCompleter.greedy=True
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.15</span>
#         </div>

# %% [markdown]
# ## Load data and initial overview of data set
# The data set contains three files. For this analysis we will only use the file 'multipleChoiceResponses.csv'.

# %%
df = pd.read_csv('data\multipleChoiceResponses.csv', low_memory=False)

# %%
df.shape
# Out:
# (23860, 395)

# %%
df.info(max_cols=500)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23860 entries, 0 to 23859
# Data columns (total 395 columns):
# Time from Start to Finish (seconds)    23860 non-null object
# Q1                                     23860 non-null object
# Q1_OTHER_TEXT                          23860 non-null object
# Q2                                     23860 non-null object
# Q3                                     23860 non-null object
# Q4                                     23439 non-null object
# Q5                                     22948 non-null object
# Q6                                     22901 non-null object
# Q6_OTHER_TEXT                          23860 non-null object
# Q7                                     21686 non-null object
# Q7_OTHER_TEXT                          23860 non-null object
# Q8                                     21102 non-null object
# Q9                                     20186 non-null object
# Q10                                    20670 non-null object
# Q11_Part_1                             9533 non-null object
# Q11_Part_2                             5482 non-null object
# Q11_Part_3                             5234 non-null object
# Q11_Part_4                             7234 non-null object
# Q11_Part_5                             4935 non-null object
# Q11_Part_6                             3472 non-null object
# Q11_Part_7                             1193 non-null object
# Q11_OTHER_TEXT                         23860 non-null object
# Q12_MULTIPLE_CHOICE                    19199 non-null object
# Q12_Part_1_TEXT                        23860 non-null object
# Q12_Part_2_TEXT                        23860 non-null object
# Q12_Part_3_TEXT                        23860 non-null object
# Q12_Part_4_TEXT                        23860 non-null object
# Q12_Part_5_TEXT                        23860 non-null object
# Q12_OTHER_TEXT                         23860 non-null object
# Q13_Part_1                             14011 non-null object
# Q13_Part_2                             8504 non-null object
# Q13_Part_3                             7061 non-null object
# Q13_Part_4                             5083 non-null object
# Q13_Part_5                             128 non-null object
# Q13_Part_6                             3907 non-null object
# Q13_Part_7                             5672 non-null object
# Q13_Part_8                             5112 non-null object
# Q13_Part_9                             7832 non-null object
# Q13_Part_10                            5986 non-null object
# Q13_Part_11                            4241 non-null object
# Q13_Part_12                            3457 non-null object
# Q13_Part_13                            5340 non-null object
# Q13_Part_14                            475 non-null object
# Q13_Part_15                            1258 non-null object
# Q13_OTHER_TEXT                         23860 non-null object
# Q14_Part_1                             6043 non-null object
# Q14_Part_2                             3533 non-null object
# Q14_Part_3                             1305 non-null object
# Q14_Part_4                             120 non-null object
# Q14_Part_5                             1308 non-null object
# Q14_Part_6                             481 non-null object
# Q14_Part_7                             362 non-null object
# Q14_Part_8                             139 non-null object
# Q14_Part_9                             4917 non-null object
# Q14_Part_10                            7598 non-null object
# Q14_Part_11                            691 non-null object
# Q14_OTHER_TEXT                         23860 non-null object
# Q15_Part_1                             4784 non-null object
# Q15_Part_2                             7461 non-null object
# Q15_Part_3                             3806 non-null object
# Q15_Part_4                             1205 non-null object
# Q15_Part_5                             550 non-null object
# Q15_Part_6                             7104 non-null object
# Q15_Part_7                             777 non-null object
# Q15_OTHER_TEXT                         23860 non-null object
# Q16_Part_1                             15712 non-null object
# Q16_Part_2                             6686 non-null object
# Q16_Part_3                             8268 non-null object
# Q16_Part_4                             2709 non-null object
# Q16_Part_5                             4000 non-null object
# Q16_Part_6                             3250 non-null object
# Q16_Part_7                             1275 non-null object
# Q16_Part_8                             4384 non-null object
# Q16_Part_9                             2653 non-null object
# Q16_Part_10                            789 non-null object
# Q16_Part_11                            231 non-null object
# Q16_Part_12                            395 non-null object
# Q16_Part_13                            1671 non-null object
# Q16_Part_14                            1209 non-null object
# Q16_Part_15                            343 non-null object
# Q16_Part_16                            1053 non-null object
# Q16_Part_17                            333 non-null object
# Q16_Part_18                            625 non-null object
# Q16_OTHER_TEXT                         23860 non-null object
# Q17                                    15223 non-null object
# Q17_OTHER_TEXT                         23860 non-null object
# Q18                                    18789 non-null object
# Q18_OTHER_TEXT                         23860 non-null object
# Q19_Part_1                             12250 non-null object
# Q19_Part_2                             9982 non-null object
# Q19_Part_3                             8137 non-null object
# Q19_Part_4                             3827 non-null object
# Q19_Part_5                             2056 non-null object
# Q19_Part_6                             1308 non-null object
# Q19_Part_7                             1100 non-null object
# Q19_Part_8                             595 non-null object
# Q19_Part_9                             2221 non-null object
# Q19_Part_10                            5572 non-null object
# Q19_Part_11                            529 non-null object
# Q19_Part_12                            733 non-null object
# Q19_Part_13                            5968 non-null object
# Q19_Part_14                            2100 non-null object
# Q19_Part_15                            1038 non-null object
# Q19_Part_16                            745 non-null object
# Q19_Part_17                            1102 non-null object
# Q19_Part_18                            2919 non-null object
# Q19_Part_19                            537 non-null object
# Q19_OTHER_TEXT                         23860 non-null object
# Q20                                    12990 non-null object
# Q20_OTHER_TEXT                         23860 non-null object
# Q21_Part_1                             7752 non-null object
# Q21_Part_2                             13393 non-null object
# Q21_Part_3                             220 non-null object
# Q21_Part_4                             2629 non-null object
# Q21_Part_5                             2220 non-null object
# Q21_Part_6                             5598 non-null object
# Q21_Part_7                             1908 non-null object
# Q21_Part_8                             7776 non-null object
# Q21_Part_9                             769 non-null object
# Q21_Part_10                            1014 non-null object
# Q21_Part_11                            873 non-null object
# Q21_Part_12                            1922 non-null object
# Q21_Part_13                            586 non-null object
# Q21_OTHER_TEXT                         23860 non-null object
# Q22                                    12185 non-null object
# Q22_OTHER_TEXT                         23860 non-null object
# Q23                                    18548 non-null object
# Q24                                    18534 non-null object
# Q25                                    18492 non-null object
# Q26                                    18481 non-null object
# Q27_Part_1                             3873 non-null object
# Q27_Part_2                             2206 non-null object
# Q27_Part_3                             767 non-null object
# Q27_Part_4                             1383 non-null object
# Q27_Part_5                             617 non-null object
# Q27_Part_6                             1692 non-null object
# Q27_Part_7                             1200 non-null object
# Q27_Part_8                             496 non-null object
# Q27_Part_9                             1457 non-null object
# Q27_Part_10                            473 non-null object
# Q27_Part_11                            556 non-null object
# Q27_Part_12                            120 non-null object
# Q27_Part_13                            232 non-null object
# Q27_Part_14                            237 non-null object
# Q27_Part_15                            346 non-null object
# Q27_Part_16                            165 non-null object
# Q27_Part_17                            159 non-null object
# Q27_Part_18                            323 non-null object
# Q27_Part_19                            3377 non-null object
# Q27_Part_20                            390 non-null object
# Q27_OTHER_TEXT                         23860 non-null object
# Q28_Part_1                             119 non-null object
# Q28_Part_2                             625 non-null object
# Q28_Part_3                             300 non-null object
# Q28_Part_4                             665 non-null object
# Q28_Part_5                             133 non-null object
# Q28_Part_6                             623 non-null object
# Q28_Part_7                             161 non-null object
# Q28_Part_8                             531 non-null object
# Q28_Part_9                             210 non-null object
# Q28_Part_10                            173 non-null object
# Q28_Part_11                            131 non-null object
# Q28_Part_12                            175 non-null object
# Q28_Part_13                            433 non-null object
# Q28_Part_14                            487 non-null object
# Q28_Part_15                            666 non-null object
# Q28_Part_16                            251 non-null object
# Q28_Part_17                            284 non-null object
# Q28_Part_18                            85 non-null object
# Q28_Part_19                            859 non-null object
# Q28_Part_20                            224 non-null object
# Q28_Part_21                            625 non-null object
# Q28_Part_22                            18 non-null object
# Q28_Part_23                            120 non-null object
# Q28_Part_24                            32 non-null object
# Q28_Part_25                            811 non-null object
# Q28_Part_26                            759 non-null object
# Q28_Part_27                            460 non-null object
# Q28_Part_28                            160 non-null object
# Q28_Part_29                            130 non-null object
# Q28_Part_30                            118 non-null object
# Q28_Part_31                            260 non-null object
# Q28_Part_32                            185 non-null object
# Q28_Part_33                            89 non-null object
# Q28_Part_34                            462 non-null object
# Q28_Part_35                            197 non-null object
# Q28_Part_36                            330 non-null object
# Q28_Part_37                            249 non-null object
# Q28_Part_38                            296 non-null object
# Q28_Part_39                            213 non-null object
# Q28_Part_40                            490 non-null object
# Q28_Part_41                            334 non-null object
# Q28_Part_42                            5371 non-null object
# Q28_Part_43                            260 non-null object
# Q28_OTHER_TEXT                         23860 non-null object
# Q29_Part_1                             899 non-null object
# Q29_Part_2                             315 non-null object
# Q29_Part_3                             616 non-null object
# Q29_Part_4                             104 non-null object
# Q29_Part_5                             731 non-null object
# Q29_Part_6                             516 non-null object
# Q29_Part_7                             514 non-null object
# Q29_Part_8                             200 non-null object
# Q29_Part_9                             3125 non-null object
# Q29_Part_10                            6189 non-null object
# Q29_Part_11                            3853 non-null object
# Q29_Part_12                            3730 non-null object
# Q29_Part_13                            2416 non-null object
# Q29_Part_14                            60 non-null object
# Q29_Part_15                            1355 non-null object
# Q29_Part_16                            39 non-null object
# Q29_Part_17                            72 non-null object
# Q29_Part_18                            121 non-null object
# Q29_Part_19                            253 non-null object
# Q29_Part_20                            214 non-null object
# Q29_Part_21                            669 non-null object
# Q29_Part_22                            138 non-null object
# Q29_Part_23                            67 non-null object
# Q29_Part_24                            62 non-null object
# Q29_Part_25                            54 non-null object
# Q29_Part_26                            256 non-null object
# Q29_Part_27                            1363 non-null object
# Q29_Part_28                            564 non-null object
# Q29_OTHER_TEXT                         23860 non-null object
# Q30_Part_1                             622 non-null object
# Q30_Part_2                             213 non-null object
# Q30_Part_3                             238 non-null object
# Q30_Part_4                             386 non-null object
# Q30_Part_5                             213 non-null object
# Q30_Part_6                             335 non-null object
# Q30_Part_7                             287 non-null object
# Q30_Part_8                             384 non-null object
# Q30_Part_9                             943 non-null object
# Q30_Part_10                            1206 non-null object
# Q30_Part_11                            598 non-null object
# Q30_Part_12                            422 non-null object
# Q30_Part_13                            212 non-null object
# Q30_Part_14                            126 non-null object
# Q30_Part_15                            62 non-null object
# Q30_Part_16                            240 non-null object
# Q30_Part_17                            832 non-null object
# Q30_Part_18                            284 non-null object
# Q30_Part_19                            240 non-null object
# Q30_Part_20                            164 non-null object
# Q30_Part_21                            68 non-null object
# Q30_Part_22                            142 non-null object
# Q30_Part_23                            82 non-null object
# Q30_Part_24                            5390 non-null object
# Q30_Part_25                            267 non-null object
# Q30_OTHER_TEXT                         23860 non-null object
# Q31_Part_1                             954 non-null object
# Q31_Part_2                             8150 non-null object
# Q31_Part_3                             1055 non-null object
# Q31_Part_4                             2246 non-null object
# Q31_Part_5                             5388 non-null object
# Q31_Part_6                             11025 non-null object
# Q31_Part_7                             2553 non-null object
# Q31_Part_8                             7395 non-null object
# Q31_Part_9                             8730 non-null object
# Q31_Part_10                            7780 non-null object
# Q31_Part_11                            1384 non-null object
# Q31_Part_12                            406 non-null object
# Q31_OTHER_TEXT                         23860 non-null object
# Q32                                    13879 non-null object
# Q32_OTHER                              23860 non-null object
# Q33_Part_1                             4758 non-null object
# Q33_Part_2                             4104 non-null object
# Q33_Part_3                             2809 non-null object
# Q33_Part_4                             8176 non-null object
# Q33_Part_5                             5226 non-null object
# Q33_Part_6                             2998 non-null object
# Q33_Part_7                             7014 non-null object
# Q33_Part_8                             3685 non-null object
# Q33_Part_9                             6076 non-null object
# Q33_Part_10                            2028 non-null object
# Q33_Part_11                            450 non-null object
# Q33_OTHER_TEXT                         23860 non-null object
# Q34_Part_1                             15938 non-null object
# Q34_Part_2                             15938 non-null object
# Q34_Part_3                             15938 non-null object
# Q34_Part_4                             15938 non-null object
# Q34_Part_5                             15938 non-null object
# Q34_Part_6                             15938 non-null object
# Q34_OTHER_TEXT                         23860 non-null object
# Q35_Part_1                             15746 non-null object
# Q35_Part_2                             15746 non-null object
# Q35_Part_3                             15746 non-null object
# Q35_Part_4                             15746 non-null object
# Q35_Part_5                             15746 non-null object
# Q35_Part_6                             15746 non-null object
# Q35_OTHER_TEXT                         23860 non-null object
# Q36_Part_1                             3677 non-null object
# Q36_Part_2                             9027 non-null object
# Q36_Part_3                             3664 non-null object
# Q36_Part_4                             4246 non-null object
# Q36_Part_5                             709 non-null object
# Q36_Part_6                             4003 non-null object
# Q36_Part_7                             1571 non-null object
# Q36_Part_8                             1041 non-null object
# Q36_Part_9                             4331 non-null object
# Q36_Part_10                            280 non-null object
# Q36_Part_11                            1953 non-null object
# Q36_Part_12                            1977 non-null object
# Q36_Part_13                            1245 non-null object
# Q36_OTHER_TEXT                         23860 non-null object
# Q37                                    9671 non-null object
# Q37_OTHER_TEXT                         23860 non-null object
# Q38_Part_1                             3139 non-null object
# Q38_Part_2                             2013 non-null object
# Q38_Part_3                             3060 non-null object
# Q38_Part_4                             5564 non-null object
# Q38_Part_5                             764 non-null object
# Q38_Part_6                             2025 non-null object
# Q38_Part_7                             223 non-null object
# Q38_Part_8                             543 non-null object
# Q38_Part_9                             605 non-null object
# Q38_Part_10                            1544 non-null object
# Q38_Part_11                            3143 non-null object
# Q38_Part_12                            2150 non-null object
# Q38_Part_13                            684 non-null object
# Q38_Part_14                            3051 non-null object
# Q38_Part_15                            1539 non-null object
# Q38_Part_16                            317 non-null object
# Q38_Part_17                            672 non-null object
# Q38_Part_18                            5012 non-null object
# Q38_Part_19                            1 non-null object
# Q38_Part_20                            1 non-null object
# Q38_Part_21                            3105 non-null object
# Q38_Part_22                            1561 non-null object
# Q38_OTHER_TEXT                         23860 non-null object
# Q39_Part_1                             15980 non-null object
# Q39_Part_2                             15980 non-null object
# Q40                                    15880 non-null object
# Q41_Part_1                             14937 non-null object
# Q41_Part_2                             14937 non-null object
# Q41_Part_3                             14937 non-null object
# Q42_Part_1                             5581 non-null object
# Q42_Part_2                             8417 non-null object
# Q42_Part_3                             2794 non-null object
# Q42_Part_4                             3118 non-null object
# Q42_Part_5                             292 non-null object
# Q42_OTHER_TEXT                         23860 non-null object
# Q43                                    13120 non-null object
# Q44_Part_1                             3298 non-null object
# Q44_Part_2                             3705 non-null object
# Q44_Part_3                             5299 non-null object
# Q44_Part_4                             4616 non-null object
# Q44_Part_5                             450 non-null object
# Q44_Part_6                             4037 non-null object
# Q45_Part_1                             1692 non-null object
# Q45_Part_2                             4739 non-null object
# Q45_Part_3                             5417 non-null object
# Q45_Part_4                             5763 non-null object
# Q45_Part_5                             5575 non-null object
# Q45_Part_6                             1489 non-null object
# Q46                                    13290 non-null object
# Q47_Part_1                             3609 non-null object
# Q47_Part_2                             5418 non-null object
# Q47_Part_3                             6000 non-null object
# Q47_Part_4                             3502 non-null object
# Q47_Part_5                             1872 non-null object
# Q47_Part_6                             4355 non-null object
# Q47_Part_7                             1001 non-null object
# Q47_Part_8                             7605 non-null object
# Q47_Part_9                             3640 non-null object
# Q47_Part_10                            3102 non-null object
# Q47_Part_11                            926 non-null object
# Q47_Part_12                            523 non-null object
# Q47_Part_13                            737 non-null object
# Q47_Part_14                            2068 non-null object
# Q47_Part_15                            245 non-null object
# Q47_Part_16                            131 non-null object
# Q48                                    13369 non-null object
# Q49_Part_1                             5637 non-null object
# Q49_Part_2                             4567 non-null object
# Q49_Part_3                             2946 non-null object
# Q49_Part_4                             2681 non-null object
# Q49_Part_5                             1478 non-null object
# Q49_Part_6                             8053 non-null object
# Q49_Part_7                             7782 non-null object
# Q49_Part_8                             4615 non-null object
# Q49_Part_9                             3666 non-null object
# Q49_Part_10                            4367 non-null object
# Q49_Part_11                            986 non-null object
# Q49_Part_12                            245 non-null object
# Q49_OTHER_TEXT                         23860 non-null object
# Q50_Part_1                             1372 non-null object
# Q50_Part_2                             6479 non-null object
# Q50_Part_3                             2675 non-null object
# Q50_Part_4                             2105 non-null object
# Q50_Part_5                             3570 non-null object
# Q50_Part_6                             1060 non-null object
# Q50_Part_7                             2501 non-null object
# Q50_Part_8                             521 non-null object
# Q50_OTHER_TEXT                         23860 non-null object
# dtypes: object(395)
# memory usage: 71.9+ MB

# %%
df.head()
# Out:
#   Time from Start to Finish (seconds)                                      Q1  \
# 0               Duration (in seconds)  What is your gender? - Selected Choice
# 1                                 710                                  Female
# 2                                 434                                    Male
# 3                                 718                                  Female
# 4                                 621                                    Male
#
#                                        Q1_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                             Q2                                         Q3  \
# 0  What is your age (# years)?  In which country do you currently reside?
# 1                        45-49                   United States of America
# 2                        30-34                                  Indonesia
# 3                        30-34                   United States of America
# 4                        35-39                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                  Bachelor’s degree
# 3                                    Master’s degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Which best describes your undergraduate major?...
# 1                                              Other
# 2                 Engineering (non-computer focused)
# 3      Computer science (software engineering, etc.)
# 4  Social sciences (anthropology, psychology, soc...
#
#                                                   Q6  \
# 0  Select the title most similar to your current ...
# 1                                         Consultant
# 2                                              Other
# 3                                     Data Scientist
# 4                                       Not employed
#
#                                        Q6_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
# 2                                                  0
# 3                                                 -1
# 4                                                 -1
#
#                                                   Q7  \
# 0  In what industry is your current employer/cont...
# 1                                              Other
# 2                          Manufacturing/Fabrication
# 3                                     I am a student
# 4                                                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                       Q49_OTHER_TEXT  \
# 0  What tools and methods do you use to make your...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                           Q50_Part_1  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_2  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                 Too time-consuming
# 4                                                NaN
#
#                                           Q50_Part_3  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4              Requires too much technical knowledge
#
#                                           Q50_Part_4  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_5  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4             Not enough incentives to share my work
#
#                                           Q50_Part_6  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_7  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_8  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q50_OTHER_TEXT
# 0  What barriers prevent you from making your wor...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
# [5 rows x 395 columns]

# %%
# renaming columns of interest to more meaningful names
df.rename(index=str, columns={'Q1': 'Gender',
                              'Q2': 'Age_Group',
                              'Q3': 'Country',
                              'Q9': 'Pay_Group'}, inplace=True)

# %% [markdown]
# #### row zero contains the questions - drop this from the dataframe and store it separately:

# %%
dfQuestions = df.iloc[0,:].copy()

# %%
df.drop(['0'], axis=0, inplace = True)

# %%
pd.set_option('max_colwidth',80)
pd.set_option("display.max_rows", 400)
dfQuestions
# Out:
# Time from Start to Finish (seconds)                                                              Duration (in seconds)
# Gender                                                                          What is your gender? - Selected Choice
# Q1_OTHER_TEXT                                                    What is your gender? - Prefer to self-describe - Text
# Age_Group                                                                                  What is your age (# years)?
# Country                                                                      In which country do you currently reside?
# Q4                                     What is the highest level of formal education that you have attained or plan...
# Q5                                                    Which best describes your undergraduate major? - Selected Choice
# Q6                                     Select the title most similar to your current role (or most recent title if ...
# Q6_OTHER_TEXT                          Select the title most similar to your current role (or most recent title if ...
# Q7                                     In what industry is your current employer/contract (or your most recent empl...
# Q7_OTHER_TEXT                          In what industry is your current employer/contract (or your most recent empl...
# Q8                                                      How many years of experience do you have in your current role?
# Pay_Group                                                 What is your current yearly compensation (approximate $USD)?
# Q10                                    Does your current employer incorporate machine learning methods into their b...
# Q11_Part_1                             Select any activities that make up an important part of your role at work: (...
# Q11_Part_2                             Select any activities that make up an important part of your role at work: (...
# Q11_Part_3                             Select any activities that make up an important part of your role at work: (...
# Q11_Part_4                             Select any activities that make up an important part of your role at work: (...
# Q11_Part_5                             Select any activities that make up an important part of your role at work: (...
# Q11_Part_6                             Select any activities that make up an important part of your role at work: (...
# Q11_Part_7                             Select any activities that make up an important part of your role at work: (...
# Q11_OTHER_TEXT                         Select any activities that make up an important part of your role at work: (...
# Q12_MULTIPLE_CHOICE                    What is the primary tool that you use at work or school to analyze data? (in...
# Q12_Part_1_TEXT                        What is the primary tool that you use at work or school to analyze data? (in...
# Q12_Part_2_TEXT                        What is the primary tool that you use at work or school to analyze data? (in...
# Q12_Part_3_TEXT                        What is the primary tool that you use at work or school to analyze data? (in...
# Q12_Part_4_TEXT                        What is the primary tool that you use at work or school to analyze data? (in...
# Q12_Part_5_TEXT                        What is the primary tool that you use at work or school to analyze data? (in...
# Q12_OTHER_TEXT                         What is the primary tool that you use at work or school to analyze data? (in...
# Q13_Part_1                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_2                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_3                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_4                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_5                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_6                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_7                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_8                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_9                             Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_10                            Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_11                            Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_12                            Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_13                            Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_14                            Which of the following integrated development environments (IDE's) have you ...
# Q13_Part_15                            Which of the following integrated development environments (IDE's) have you ...
# Q13_OTHER_TEXT                         Which of the following integrated development environments (IDE's) have you ...
# Q14_Part_1                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_2                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_3                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_4                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_5                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_6                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_7                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_8                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_9                             Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_10                            Which of the following hosted notebooks have you used at work or school in t...
# Q14_Part_11                            Which of the following hosted notebooks have you used at work or school in t...
# Q14_OTHER_TEXT                         Which of the following hosted notebooks have you used at work or school in t...
# Q15_Part_1                             Which of the following cloud computing services have you used at work or sch...
# Q15_Part_2                             Which of the following cloud computing services have you used at work or sch...
# Q15_Part_3                             Which of the following cloud computing services have you used at work or sch...
# Q15_Part_4                             Which of the following cloud computing services have you used at work or sch...
# Q15_Part_5                             Which of the following cloud computing services have you used at work or sch...
# Q15_Part_6                             Which of the following cloud computing services have you used at work or sch...
# Q15_Part_7                             Which of the following cloud computing services have you used at work or sch...
# Q15_OTHER_TEXT                         Which of the following cloud computing services have you used at work or sch...
# Q16_Part_1                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_2                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_3                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_4                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_5                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_6                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_7                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_8                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_9                             What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_10                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_11                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_12                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_13                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_14                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_15                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_16                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_17                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_Part_18                            What programming languages do you use on a regular basis? (Select all that a...
# Q16_OTHER_TEXT                         What programming languages do you use on a regular basis? (Select all that a...
# Q17                                        What specific programming language do you use most often? - Selected Choice
# Q17_OTHER_TEXT                                What specific programming language do you use most often? - Other - Text
# Q18                                    What programming language would you recommend an aspiring data scientist to ...
# Q18_OTHER_TEXT                         What programming language would you recommend an aspiring data scientist to ...
# Q19_Part_1                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_2                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_3                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_4                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_5                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_6                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_7                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_8                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_9                             What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_10                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_11                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_12                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_13                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_14                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_15                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_16                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_17                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_18                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_Part_19                            What machine learning frameworks have you used in the past 5 years? (Select ...
# Q19_OTHER_TEXT                         What machine learning frameworks have you used in the past 5 years? (Select ...
# Q20                                    Of the choices that you selected in the previous question, which ML library ...
# Q20_OTHER_TEXT                         Of the choices that you selected in the previous question, which ML library ...
# Q21_Part_1                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_2                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_3                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_4                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_5                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_6                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_7                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_8                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_9                             What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_10                            What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_11                            What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_12                            What data visualization libraries or tools have you used in the past 5 years...
# Q21_Part_13                            What data visualization libraries or tools have you used in the past 5 years...
# Q21_OTHER_TEXT                         What data visualization libraries or tools have you used in the past 5 years...
# Q22                                    Of the choices that you selected in the previous question, which specific da...
# Q22_OTHER_TEXT                         Of the choices that you selected in the previous question, which specific da...
# Q23                                    Approximately what percent of your time at work or school is spent actively ...
# Q24                                                               How long have you been writing code to analyze data?
# Q25                                    For how many years have you used machine learning methods (at work or in sch...
# Q26                                                                   Do you consider yourself to be a data scientist?
# Q27_Part_1                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_2                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_3                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_4                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_5                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_6                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_7                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_8                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_9                             Which of the following cloud computing products have you used at work or sch...
# Q27_Part_10                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_11                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_12                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_13                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_14                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_15                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_16                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_17                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_18                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_19                            Which of the following cloud computing products have you used at work or sch...
# Q27_Part_20                            Which of the following cloud computing products have you used at work or sch...
# Q27_OTHER_TEXT                         Which of the following cloud computing products have you used at work or sch...
# Q28_Part_1                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_2                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_3                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_4                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_5                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_6                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_7                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_8                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_9                             Which of the following machine learning products have you used at work or sc...
# Q28_Part_10                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_11                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_12                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_13                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_14                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_15                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_16                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_17                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_18                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_19                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_20                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_21                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_22                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_23                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_24                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_25                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_26                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_27                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_28                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_29                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_30                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_31                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_32                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_33                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_34                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_35                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_36                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_37                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_38                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_39                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_40                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_41                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_42                            Which of the following machine learning products have you used at work or sc...
# Q28_Part_43                            Which of the following machine learning products have you used at work or sc...
# Q28_OTHER_TEXT                         Which of the following machine learning products have you used at work or sc...
# Q29_Part_1                             Which of the following relational database products have you used at work or...
# Q29_Part_2                             Which of the following relational database products have you used at work or...
# Q29_Part_3                             Which of the following relational database products have you used at work or...
# Q29_Part_4                             Which of the following relational database products have you used at work or...
# Q29_Part_5                             Which of the following relational database products have you used at work or...
# Q29_Part_6                             Which of the following relational database products have you used at work or...
# Q29_Part_7                             Which of the following relational database products have you used at work or...
# Q29_Part_8                             Which of the following relational database products have you used at work or...
# Q29_Part_9                             Which of the following relational database products have you used at work or...
# Q29_Part_10                            Which of the following relational database products have you used at work or...
# Q29_Part_11                            Which of the following relational database products have you used at work or...
# Q29_Part_12                            Which of the following relational database products have you used at work or...
# Q29_Part_13                            Which of the following relational database products have you used at work or...
# Q29_Part_14                            Which of the following relational database products have you used at work or...
# Q29_Part_15                            Which of the following relational database products have you used at work or...
# Q29_Part_16                            Which of the following relational database products have you used at work or...
# Q29_Part_17                            Which of the following relational database products have you used at work or...
# Q29_Part_18                            Which of the following relational database products have you used at work or...
# Q29_Part_19                            Which of the following relational database products have you used at work or...
# Q29_Part_20                            Which of the following relational database products have you used at work or...
# Q29_Part_21                            Which of the following relational database products have you used at work or...
# Q29_Part_22                            Which of the following relational database products have you used at work or...
# Q29_Part_23                            Which of the following relational database products have you used at work or...
# Q29_Part_24                            Which of the following relational database products have you used at work or...
# Q29_Part_25                            Which of the following relational database products have you used at work or...
# Q29_Part_26                            Which of the following relational database products have you used at work or...
# Q29_Part_27                            Which of the following relational database products have you used at work or...
# Q29_Part_28                            Which of the following relational database products have you used at work or...
# Q29_OTHER_TEXT                         Which of the following relational database products have you used at work or...
# Q30_Part_1                             Which of the following big data and analytics products have you used at work...
# Q30_Part_2                             Which of the following big data and analytics products have you used at work...
# Q30_Part_3                             Which of the following big data and analytics products have you used at work...
# Q30_Part_4                             Which of the following big data and analytics products have you used at work...
# Q30_Part_5                             Which of the following big data and analytics products have you used at work...
# Q30_Part_6                             Which of the following big data and analytics products have you used at work...
# Q30_Part_7                             Which of the following big data and analytics products have you used at work...
# Q30_Part_8                             Which of the following big data and analytics products have you used at work...
# Q30_Part_9                             Which of the following big data and analytics products have you used at work...
# Q30_Part_10                            Which of the following big data and analytics products have you used at work...
# Q30_Part_11                            Which of the following big data and analytics products have you used at work...
# Q30_Part_12                            Which of the following big data and analytics products have you used at work...
# Q30_Part_13                            Which of the following big data and analytics products have you used at work...
# Q30_Part_14                            Which of the following big data and analytics products have you used at work...
# Q30_Part_15                            Which of the following big data and analytics products have you used at work...
# Q30_Part_16                            Which of the following big data and analytics products have you used at work...
# Q30_Part_17                            Which of the following big data and analytics products have you used at work...
# Q30_Part_18                            Which of the following big data and analytics products have you used at work...
# Q30_Part_19                            Which of the following big data and analytics products have you used at work...
# Q30_Part_20                            Which of the following big data and analytics products have you used at work...
# Q30_Part_21                            Which of the following big data and analytics products have you used at work...
# Q30_Part_22                            Which of the following big data and analytics products have you used at work...
# Q30_Part_23                            Which of the following big data and analytics products have you used at work...
# Q30_Part_24                            Which of the following big data and analytics products have you used at work...
# Q30_Part_25                            Which of the following big data and analytics products have you used at work...
# Q30_OTHER_TEXT                         Which of the following big data and analytics products have you used at work...
# Q31_Part_1                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_2                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_3                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_4                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_5                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_6                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_7                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_8                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_9                             Which types of data do you currently interact with most often at work or sch...
# Q31_Part_10                            Which types of data do you currently interact with most often at work or sch...
# Q31_Part_11                            Which types of data do you currently interact with most often at work or sch...
# Q31_Part_12                            Which types of data do you currently interact with most often at work or sch...
# Q31_OTHER_TEXT                         Which types of data do you currently interact with most often at work or sch...
# Q32                                    What is the type of data that you currently interact with most often at work...
# Q32_OTHER                              What is the type of data that you currently interact with most often at work...
# Q33_Part_1                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_2                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_3                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_4                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_5                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_6                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_7                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_8                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_9                             Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_10                            Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_Part_11                            Where do you find public datasets? (Select all that apply) - Selected Choice...
# Q33_OTHER_TEXT                               Where do you find public datasets? (Select all that apply) - Other - Text
# Q34_Part_1                             During a typical data science project at work or school, approximately what ...
# Q34_Part_2                             During a typical data science project at work or school, approximately what ...
# Q34_Part_3                             During a typical data science project at work or school, approximately what ...
# Q34_Part_4                             During a typical data science project at work or school, approximately what ...
# Q34_Part_5                             During a typical data science project at work or school, approximately what ...
# Q34_Part_6                             During a typical data science project at work or school, approximately what ...
# Q34_OTHER_TEXT                         During a typical data science project at work or school, approximately what ...
# Q35_Part_1                             What percentage of your current machine learning/data science training falls...
# Q35_Part_2                             What percentage of your current machine learning/data science training falls...
# Q35_Part_3                             What percentage of your current machine learning/data science training falls...
# Q35_Part_4                             What percentage of your current machine learning/data science training falls...
# Q35_Part_5                             What percentage of your current machine learning/data science training falls...
# Q35_Part_6                             What percentage of your current machine learning/data science training falls...
# Q35_OTHER_TEXT                         What percentage of your current machine learning/data science training falls...
# Q36_Part_1                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_2                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_3                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_4                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_5                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_6                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_7                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_8                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_9                             On which online platforms have you begun or completed data science courses? ...
# Q36_Part_10                            On which online platforms have you begun or completed data science courses? ...
# Q36_Part_11                            On which online platforms have you begun or completed data science courses? ...
# Q36_Part_12                            On which online platforms have you begun or completed data science courses? ...
# Q36_Part_13                            On which online platforms have you begun or completed data science courses? ...
# Q36_OTHER_TEXT                         On which online platforms have you begun or completed data science courses? ...
# Q37                                    On which online platform have you spent the most amount of time? - Selected ...
# Q37_OTHER_TEXT                         On which online platform have you spent the most amount of time? - Other - Text
# Q38_Part_1                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_2                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_3                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_4                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_5                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_6                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_7                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_8                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_9                             Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_10                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_11                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_12                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_13                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_14                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_15                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_16                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_17                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_18                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_19                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_20                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_21                            Who/what are your favorite media sources that report on data science topics?...
# Q38_Part_22                            Who/what are your favorite media sources that report on data science topics?...
# Q38_OTHER_TEXT                         Who/what are your favorite media sources that report on data science topics?...
# Q39_Part_1                             How do you perceive the quality of online learning platforms and in-person b...
# Q39_Part_2                             How do you perceive the quality of online learning platforms and in-person b...
# Q40                                    Which better demonstrates expertise in data science: academic achievements o...
# Q41_Part_1                             How do you perceive the importance of the following topics? - Fairness and b...
# Q41_Part_2                             How do you perceive the importance of the following topics? - Being able to ...
# Q41_Part_3                             How do you perceive the importance of the following topics? - Reproducibilit...
# Q42_Part_1                             What metrics do you or your organization use to determine whether or not you...
# Q42_Part_2                             What metrics do you or your organization use to determine whether or not you...
# Q42_Part_3                             What metrics do you or your organization use to determine whether or not you...
# Q42_Part_4                             What metrics do you or your organization use to determine whether or not you...
# Q42_Part_5                             What metrics do you or your organization use to determine whether or not you...
# Q42_OTHER_TEXT                         What metrics do you or your organization use to determine whether or not you...
# Q43                                    Approximately what percent of your data projects involved exploring unfair b...
# Q44_Part_1                             What do you find most difficult about ensuring that your algorithms are fair...
# Q44_Part_2                             What do you find most difficult about ensuring that your algorithms are fair...
# Q44_Part_3                             What do you find most difficult about ensuring that your algorithms are fair...
# Q44_Part_4                             What do you find most difficult about ensuring that your algorithms are fair...
# Q44_Part_5                             What do you find most difficult about ensuring that your algorithms are fair...
# Q44_Part_6                             What do you find most difficult about ensuring that your algorithms are fair...
# Q45_Part_1                             In what circumstances would you explore model insights and interpret your mo...
# Q45_Part_2                             In what circumstances would you explore model insights and interpret your mo...
# Q45_Part_3                             In what circumstances would you explore model insights and interpret your mo...
# Q45_Part_4                             In what circumstances would you explore model insights and interpret your mo...
# Q45_Part_5                             In what circumstances would you explore model insights and interpret your mo...
# Q45_Part_6                             In what circumstances would you explore model insights and interpret your mo...
# Q46                                    Approximately what percent of your data projects involve exploring model ins...
# Q47_Part_1                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_2                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_3                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_4                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_5                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_6                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_7                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_8                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_9                             What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_10                            What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_11                            What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_12                            What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_13                            What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_14                            What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_15                            What methods do you prefer for explaining and/or interpreting decisions that...
# Q47_Part_16                            What methods do you prefer for explaining and/or interpreting decisions that...
# Q48                                    Do you consider ML models to be "black boxes" with outputs that are difficul...
# Q49_Part_1                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_2                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_3                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_4                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_5                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_6                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_7                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_8                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_9                             What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_10                            What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_11                            What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_Part_12                            What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q49_OTHER_TEXT                         What tools and methods do you use to make your work easy to reproduce? (Sele...
# Q50_Part_1                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_Part_2                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_Part_3                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_Part_4                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_Part_5                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_Part_6                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_Part_7                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_Part_8                             What barriers prevent you from making your work even easier to reuse and rep...
# Q50_OTHER_TEXT                         What barriers prevent you from making your work even easier to reuse and rep...
# Name: 0, dtype: object

# %% [markdown]
# ## Question 1: What are some of the demographics of the survey respondents?

# %%
df.describe()
# Out:
#        Time from Start to Finish (seconds) Gender Q1_OTHER_TEXT Age_Group  \
# count                                23859  23859         23859     23859
# unique                                6522      4            67        12
# top                                    101   Male            -1     25-29
# freq                                    31  19430         23780      6159
#
#                          Country               Q4  \
# count                      23859            23438
# unique                        58                7
# top     United States of America  Master’s degree
# freq                        4716            10855
#
#                                                    Q5       Q6 Q6_OTHER_TEXT  \
# count                                           22947    22900         23859
# unique                                             13       21           863
# top     Computer science (software engineering, etc.)  Student            -1
# freq                                             9430     5253         22537
#
#                           Q7      ...       Q49_OTHER_TEXT     Q50_Part_1  \
# count                  21685      ...                23859           1371
# unique                    19      ...                  169              1
# top     Computers/Technology      ...                   -1  Too expensive
# freq                    5584      ...                23689           1371
#
#                 Q50_Part_2                             Q50_Part_3  \
# count                 6478                                   2674
# unique                   1                                      1
# top     Too time-consuming  Requires too much technical knowledge
# freq                  6478                                   2674
#
#                                                               Q50_Part_4  \
# count                                                               2104
# unique                                                                 1
# top     Afraid that others will use my work without giving proper credit
# freq                                                                2104
#
#                                     Q50_Part_5  \
# count                                     3569
# unique                                       1
# top     Not enough incentives to share my work
# freq                                      3569
#
#                                                                   Q50_Part_6  \
# count                                                                   1059
# unique                                                                     1
# top     I had never considered making my work easier for others to reproduce
# freq                                                                    1059
#
#                                Q50_Part_7 Q50_Part_8 Q50_OTHER_TEXT
# count                                2500        520          23859
# unique                                  1          1            409
# top     None of these reasons apply to me      Other             -1
# freq                                 2500        520          23428
#
# [4 rows x 395 columns]

# %%
# bar plot of respondents by country

topx = 20 # use zero to show all or number. eg topx =10 for top 10

ax = df.Country.value_counts(ascending=True)[-topx:].plot(kind = 'barh', color = 'blue')
ax.set_title(dfQuestions.Country + ' (Top ' + str(topx) + ')')
ax.set_xlabel('number of responses')
plt.rcParams['figure.figsize'] = [16,12]
plt.savefig('images\img-top20-countries.jpg')
plt.show()

# %% [markdown]
# #### Most survey answers came from the US, India, and China - let's look into gender and age distributions in those countries:

# %%
df_top3_countries = df[(df.Country == 'United States of America') | (df.Country == 'India') | (df.Country == 'China')].copy()

# %%
sns.countplot(data = df_top3_countries, x = 'Country', hue= 'Gender')
plt.title('Gender split for top 3 countries')
plt.rcParams['figure.figsize'] = [6,5]
plt.savefig('images\img-top3-countries-gendersplit.jpg')
plt.show()

# %%
# counts by country
df_top3_countries.groupby(['Country'])['Gender'].count()
# Out:
# Country
# China                       1644
# India                       4417
# United States of America    4716
# Name: Gender, dtype: int64

# %%
# counts by country and gender
df_top3_countries.groupby(['Country'])['Gender'].value_counts()
# Out:
# Country                   Gender
# China                     Male                       1337
#                           Female                      267
#                           Prefer not to say            38
#                           Prefer to self-describe       2
# India                     Male                       3719
#                           Female                      657
#                           Prefer not to say            37
#                           Prefer to self-describe       4
# United States of America  Male                       3530
#                           Female                     1082
#                           Prefer not to say            77
#                           Prefer to self-describe      27
# Name: Gender, dtype: int64

# %%
# percentages by country by gender
100.00 * df_top3_countries.groupby(['Country', 'Gender'])['Gender'].count() / df_top3_countries.groupby(['Country'])['Gender'].count()
# Out:
# Country                   Gender
# China                     Female                     16.240876
#                           Male                       81.326034
#                           Prefer not to say           2.311436
#                           Prefer to self-describe     0.121655
# India                     Female                     14.874349
#                           Male                       84.197419
#                           Prefer not to say           0.837673
#                           Prefer to self-describe     0.090559
# United States of America  Female                     22.943172
#                           Male                       74.851569
#                           Prefer not to say           1.632740
#                           Prefer to self-describe     0.572519
# Name: Gender, dtype: float64

# %% [markdown]
# #### The US has a higher percentage of female respondents than China and India

# %%
# sorting the age categories for the count plot
sorted_age_groups = sorted(df_top3_countries.Age_Group.value_counts().index)

fig, ax = plt.subplots(2, 1, figsize=(7,7))
fig.suptitle('Age split by gender for top 3 countries')

ax[0].set_title('Males')
sns.countplot(data = df_top3_countries[df_top3_countries.Gender == 'Male'], 
              x = 'Country',
              order = ['United States of America', 'India', 'China'],
              hue= 'Age_Group',
              hue_order = sorted_age_groups,
              ax = ax[0])


ax[1].set_title('Females')
sns.countplot(data = df_top3_countries[df_top3_countries.Gender == 'Female'], 
              x = 'Country',
              order = ['United States of America', 'India', 'China'],
              hue= 'Age_Group',
              hue_order = sorted_age_groups,
              ax = ax[1])

fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.legend(loc='best')
plt.rcParams['figure.figsize'] = [7,7]
plt.savefig('images\img-top3-countries-agesplit.jpg')
plt.show()

# %% [markdown]
# #### The survey participants from India are much younger than those from the US or China. Especially, young males are overrepresented.

# %%
# average ages by country and gender
df_top3_countries \
    .loc[((df_top3_countries.Gender == 'Female') | (df_top3_countries.Gender == 'Male'))] \
    .pivot_table(values='Age', 
                 index=['Gender'],
                 columns=['Country'], 
                 aggfunc=[np.mean],
                 margins=True) \
    .style.background_gradient(axis='rows', subset=['mean'], cmap=sns.light_palette("green", as_cmap=True)) \
    .format("{:,.2f}")
# Out:
# <style  type="text/css" >
#     #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col1 {
#             background-color:  #008000;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col0 {
#             background-color:  #008000;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col2 {
#             background-color:  #008000;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col3 {
#             background-color:  #008000;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col0 {
#             background-color:  #269526;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col1 {
#             background-color:  #c3ecc3;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col2 {
#             background-color:  #369e36;
#         }    #T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col3 {
#             background-color:  #2b982b;
#         }</style>
# <table id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=4>mean</th>
#     </tr>    <tr>
#         <th class="index_name level1" >Country</th>
#         <th class="col_heading level1 col0" >China</th>
#         <th class="col_heading level1 col1" >India</th>
#         <th class="col_heading level1 col2" >United States of America</th>
#         <th class="col_heading level1 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Gender</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4clevel0_row0" class="row_heading level0 row0" >Female</th>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col0" class="data row0 col0" >25.34</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col1" class="data row0 col1" >26.69</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col2" class="data row0 col2" >30.95</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow0_col3" class="data row0 col3" >28.81</td>
#     </tr>    <tr>
#         <th id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4clevel0_row1" class="row_heading level0 row1" >Male</th>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col0" class="data row1 col0" >26.61</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col1" class="data row1 col1" >26.60</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col2" class="data row1 col2" >33.86</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow1_col3" class="data row1 col3" >29.59</td>
#     </tr>    <tr>
#         <th id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4clevel0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col0" class="data row2 col0" >26.40</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col1" class="data row2 col1" >26.61</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col2" class="data row2 col2" >33.18</td>
#         <td id="T_d95ff8a4_0ca9_11e9_8c4a_d4bed94dff4crow2_col3" class="data row2 col3" >29.44</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## Question 2: Are there any obvious discrepancies between Age, Pay, and Gender by Country?

# %% [markdown]
# Since the Age_Group and Pay_Group are strings, need to encode those as values to use simple scatter plots, regressions, and density plots.
# We will encode each category by it's midpoint value. This is obviously and approximation but might still yield usefull overview of the data.

# %%
df_top3_countries.Age_Group.value_counts().index
# Out:
# Index(['25-29', '22-24', '18-21', '30-34', '35-39', '40-44', '45-49', '50-54',
#        '55-59', '60-69', '70-79', '80+'],
#       dtype='object')

# %%
# encode the categorical age ranges with midpoint values (assumed 35-39 to mean 35<age<40 for midpoint of 37.5)
# using midpoint is not going to give the exact distribution of age but should help determine overall shape of pay distributions

df_top3_countries['Age'] = df_top3_countries.Age_Group.map({
    '18-21': 20.0,
    '22-24': 23.75,
    '25-29': 27.5,
    '30-34': 32.5,
    '35-39': 37.5,
    '40-44': 42.5,
    '45-49': 47.5,
    '50-54': 52.5,
    '55-59': 57.5,
    '60-69': 65,
    '70-79': 75,
    '80+': 80})

# %%
# looking into compensation next:
df_top3_countries.Pay_Group.value_counts()
# Out:
# I do not wish to disclose my approximate yearly compensation    2389
# 0-10,000                                                        2108
# 10-20,000                                                        690
# 100-125,000                                                      534
# 20-30,000                                                        443
# 125-150,000                                                      376
# 150-200,000                                                      347
# 30-40,000                                                        305
# 90-100,000                                                       290
# 70-80,000                                                        278
# 80-90,000                                                        256
# 60-70,000                                                        238
# 50-60,000                                                        234
# 40-50,000                                                        205
# 200-250,000                                                      135
# 250-300,000                                                       55
# 300-400,000                                                       38
# 500,000+                                                          36
# 400-500,000                                                       15
# Name: Pay_Group, dtype: int64

# %%
# encode the categorical pay ranges with midpoint values
# using midpoint is not going to give the exact distribution of pay but should help determine overall shape of pay distributions

df_top3_countries['Pay'] = df_top3_countries.Pay_Group.map({
    'I do not wish to disclose my approximate yearly compensation': np.NaN,
    '0-10,000': 5000,
    '10-20,000': 15000,
    '100-125,000': 112500,
    '20-30,000': 25000,
    '125-150,000': 137500,
    '150-200,000': 175000,
    '30-40,000': 35000,
    '90-100,000': 95000,
    '70-80,000': 75000,
    '80-90,000': 85000,
    '60-70,000': 65000,
    '50-60,000': 55000,
    '40-50,000': 45000,
    '200-250,000': 225000,
    '250-300,000': 275000,
    '300-400,000': 350000,
    '500,000+': 500000,
    '400-500,000': 450000})

# %%
# compare payment grouping by gender and country
sns.catplot(data = (df_top3_countries.loc[((df_top3_countries.Gender == 'Female') | (df_top3_countries.Gender == 'Male')) # male or female
                                         & (df_top3_countries.Pay.notnull())]), # skip the NaNs
            x='Country', 
            hue='Gender', 
            y='Pay', 
            kind='violin',
            split=True)
plt.title('Approximated pay distribution by country and gender')
plt.savefig('images\img-top3-countries-incomedistribution.jpg')
plt.show()

# %% [markdown]
# Notice that the charts show values close to and below zero. This is an artifact of the plotting library trying to make a smooth chart of the distribution. The lowest values are 5000 in each chart.

# %%
# mean pay by gender and country
df_top3_countries.loc[((df_top3_countries.Gender == 'Female') | (df_top3_countries.Gender == 'Male'))] \
    .groupby(['Country', 'Gender'])['Pay'].mean()
# Out:
# Country                   Gender
# China                     Female     13863.636364
#                           Male       24360.304288
# India                     Female     24824.074074
#                           Male       22085.174276
# United States of America  Female     78218.664850
#                           Male      103466.564181
# Name: Pay, dtype: float64

# %% [markdown]
# note that removing the extremely high salaries would bring down the average - but these are reportedly real salaries so they can't just be removed as outliers

# %% [markdown]
# #### there appears to be a difference in pay ranges and distributions between men and women in all three countries
#
# maybe this is due to different levels of experience?

# %% [markdown]
# #### do survey takers consider themselves Data Scientists?

# %%
# we have a question on this!
dfQuestions.Q26
# Out:
# 'Do you consider yourself to be a data scientist?'

# %%
df_top3_countries.Q26.value_counts()
# Out:
# Definitely yes    2162
# Probably yes      2122
# Maybe             1821
# Probably not      1442
# Definitely not     698
# Name: Q26, dtype: int64

# %%
# encode the categorical answer with numerical values

df_top3_countries['AreYouDS'] = df_top3_countries.Q26.map({
    'Definitely not': -2,
    'Probably not': -1,
    'Maybe': 0,
    'Probably yes': 1,
    'Definitely yes': 2})

# %%
sns.countplot(data = df_top3_countries, x = 'Country', hue= 'AreYouDS')
plt.title(dfQuestions.Q26)
plt.rcParams['figure.figsize'] = [4,5]
plt.show()

# %% [markdown]
# Is there a difference between men and women?

# %%
# sorting the categories for the count plot
sorted_DS_groups = sorted(df_top3_countries.AreYouDS.value_counts().index)

fig, ax = plt.subplots(2, 1)
fig.suptitle('Are you a Data Scientist? split by gender for top 3 countries')

ax[0].set_title('Males')
sns.countplot(data = df_top3_countries[df_top3_countries.Gender == 'Male'], 
              x = 'Country',
              order = ['United States of America', 'India', 'China'],
              hue= 'AreYouDS',
              hue_order = sorted_DS_groups,
              ax = ax[0])
ax[0].legend(['Definitely not', 'Probably not', 'Maybe', 'Probably yes', 'Definitely yes'])

ax[1].set_title('Females')
sns.countplot(data = df_top3_countries[df_top3_countries.Gender == 'Female'], 
              x = 'Country',
              order = ['United States of America', 'India', 'China'],
              hue= 'AreYouDS',
              hue_order = sorted_DS_groups,
              ax = ax[1])
ax[1].legend(['Definitely not', 'Probably not', 'Maybe', 'Probably yes', 'Definitely yes'])

fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.rcParams['figure.figsize'] = [6,7]
plt.savefig('images\img-top3-countries-dataScientist-split.jpg')
plt.show()

# %%
# pay by country, gender, and how survey respondents ranked themselves on the question
# "Do you consider yourself a data scientist?"

df_top3_countries \
    .loc[((df_top3_countries.Gender == 'Female') | (df_top3_countries.Gender == 'Male'))] \
    .pivot_table(values='Pay', 
                 index=['AreYouDS', 'Q26'],
                 columns=['Country','Gender'], 
                 aggfunc=['count', np.mean],
                 margins=True) \
    .style.background_gradient(axis='rows', subset=['mean'], cmap=sns.light_palette("green", as_cmap=True)) \
    .format("{:,.0f}")
# Out:
# <style  type="text/css" >
#     #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col9 {
#             background-color:  #b0e2b0;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col10 {
#             background-color:  #c9efc9;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col11 {
#             background-color:  #bfeabf;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col13 {
#             background-color:  #c5edc5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow1_col7 {
#             background-color:  #a6dca6;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow1_col8 {
#             background-color:  #309a30;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow1_col9 {
#             background-color:  #defbde;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow1_col10 {
#             background-color:  #a8dda8;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow1_col12 {
#             background-color:  #e3fee3;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow1_col13 {
#             background-color:  #dffcdf;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow2_col7 {
#             background-color:  #d3f5d3;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow2_col8 {
#             background-color:  #2a972a;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow2_col9 {
#             background-color:  #bbe8bb;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow2_col11 {
#             background-color:  #aee0ae;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow2_col12 {
#             background-color:  #caf0ca;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow2_col13 {
#             background-color:  #e5ffe5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow3_col7 {
#             background-color:  #9bd69b;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow3_col8 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow3_col9 {
#             background-color:  #e5ffe5;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow3_col10 {
#             background-color:  #82c882;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow3_col11 {
#             background-color:  #65b865;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow3_col12 {
#             background-color:  #b6e5b6;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow3_col13 {
#             background-color:  #ade0ad;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow4_col7 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow4_col8 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow4_col9 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow4_col10 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow4_col11 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow4_col12 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow4_col13 {
#             background-color:  #008000;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow5_col7 {
#             background-color:  #8bcd8b;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow5_col8 {
#             background-color:  #1f911f;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow5_col9 {
#             background-color:  #85ca85;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow5_col10 {
#             background-color:  #82c882;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow5_col11 {
#             background-color:  #77c277;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow5_col12 {
#             background-color:  #91d091;
#         }    #T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow5_col13 {
#             background-color:  #94d294;
#         }</style>
# <table id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4c" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=7>count</th>
#         <th class="col_heading level0 col7" colspan=7>mean</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Country</th>
#         <th class="col_heading level1 col0" colspan=2>China</th>
#         <th class="col_heading level1 col2" colspan=2>India</th>
#         <th class="col_heading level1 col4" colspan=2>United States of America</th>
#         <th class="col_heading level1 col6" >All</th>
#         <th class="col_heading level1 col7" colspan=2>China</th>
#         <th class="col_heading level1 col9" colspan=2>India</th>
#         <th class="col_heading level1 col11" colspan=2>United States of America</th>
#         <th class="col_heading level1 col13" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level2" >Gender</th>
#         <th class="col_heading level2 col0" >Female</th>
#         <th class="col_heading level2 col1" >Male</th>
#         <th class="col_heading level2 col2" >Female</th>
#         <th class="col_heading level2 col3" >Male</th>
#         <th class="col_heading level2 col4" >Female</th>
#         <th class="col_heading level2 col5" >Male</th>
#         <th class="col_heading level2 col6" ></th>
#         <th class="col_heading level2 col7" >Female</th>
#         <th class="col_heading level2 col8" >Male</th>
#         <th class="col_heading level2 col9" >Female</th>
#         <th class="col_heading level2 col10" >Male</th>
#         <th class="col_heading level2 col11" >Female</th>
#         <th class="col_heading level2 col12" >Male</th>
#         <th class="col_heading level2 col13" ></th>
#     </tr>    <tr>
#         <th class="index_name level0" >AreYouDS</th>
#         <th class="index_name level1" >Q26</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4clevel0_row0" class="row_heading level0 row0" >-2.0</th>
#         <th id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4clevel1_row0" class="row_heading level1 row0" >Definitely not</th>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col0" class="data row0 col0" >7</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col1" class="data row0 col1" >34</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col2" class="data row0 col2" >18</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col3" class="data row0 col3" >148</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col4" class="data row0 col4" >59</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col5" class="data row0 col5" >225</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col6" class="data row0 col6" >491</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col7" class="data row0 col7" >7,857</td>
#         <td id="T_e371362c_0cb7_11e9_b81c_d4bed94dff4crow0_col8" class="data row0 col8" >8

# %% [markdown]
# Not enough survey responses for Chinese females in most "Are you a Data Scientist" buckets to comfortably use the mean (since we also used midpoints for the salary buckets)

# %%
sns.pairplot(df_top3_countries[['Age', 'AreYouDS', 'Pay', 'Country']], hue='Country', kind='reg')
plt.show()
# Out:
# C:\Users\Lindstaedt\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Lindstaedt\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\Lindstaedt\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.pairplot(df_top3_countries.loc[((df_top3_countries.Gender == 'Female') | (df_top3_countries.Gender == 'Male'))
                                   & (df_top3_countries.Country == 'United States of America'),
                                   ['Age', 'AreYouDS', 'Pay', 'Country', 'Gender']],
             hue='Gender', kind='reg')

# %%
df_top_countries_noNaNs = df_top3_countries[['Age', 'AreYouDS', 'Pay', 'Country','Gender']].copy().dropna(axis=0, how='any')

# %%
# checking counts by age and AreYouDS and country and gender to get a sense for amount of respondents in each cell
# for "probably" and "definitily" DS (ie 1 or 2):

df_top_countries_noNaNs \
    .loc[((df_top_countries_noNaNs.Gender == 'Female') | (df_top_countries_noNaNs.Gender == 'Male'))
           & (df_top_countries_noNaNs.Country != 'China')
           & (df_top_countries_noNaNs.AreYouDS >= 1)] \
    .pivot_table(values='Pay', 
                 index=['AreYouDS', 'Age'],
                 columns=['Country','Gender'], 
                 aggfunc=['count', np.mean],
                 margins=True) \
    .style.background_gradient(axis='rows', subset=['mean'], cmap=sns.light_palette("green", as_cmap=True)) \
    .format("{:,.0f}")
# Out:
# <style  type="text/css" >
#     #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow0_col7 {
#             background-color:  #bce8bc;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow0_col8 {
#             background-color:  #c9efc9;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow0_col9 {
#             background-color:  #e4fee4;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow1_col5 {
#             background-color:  #e2fde2;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow1_col6 {
#             background-color:  #dbf9db;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow1_col7 {
#             background-color:  #c4edc4;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow1_col8 {
#             background-color:  #c2ecc2;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow1_col9 {
#             background-color:  #d3f5d3;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow2_col5 {
#             background-color:  #d9f8d9;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow2_col6 {
#             background-color:  #d5f6d5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow2_col7 {
#             background-color:  #acdfac;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow2_col8 {
#             background-color:  #9ed89e;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow2_col9 {
#             background-color:  #b8e6b8;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow3_col5 {
#             background-color:  #d4f6d4;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow3_col6 {
#             background-color:  #ccf1cc;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow3_col7 {
#             background-color:  #9fd89f;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow3_col8 {
#             background-color:  #70be70;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow3_col9 {
#             background-color:  #91d091;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow4_col5 {
#             background-color:  #008000;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow4_col6 {
#             background-color:  #a9dea9;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow4_col7 {
#             background-color:  #89cc89;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow4_col8 {
#             background-color:  #6ebd6e;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow4_col9 {
#             background-color:  #88cb88;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow5_col5 {
#             background-color:  #8fcf8f;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow5_col6 {
#             background-color:  #c0eac0;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow5_col7 {
#             background-color:  #9ad59a;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow5_col8 {
#             background-color:  #54ae54;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow5_col9 {
#             background-color:  #7cc57c;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow6_col6 {
#             background-color:  #9cd69c;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow6_col7 {
#             background-color:  #7ac37a;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow6_col8 {
#             background-color:  #0f880f;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow6_col9 {
#             background-color:  #3ea23e;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow7_col6 {
#             background-color:  #7dc57d;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow7_col7 {
#             background-color:  #79c379;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow7_col8 {
#             background-color:  #2d992d;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow7_col9 {
#             background-color:  #4daa4d;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow8_col7 {
#             background-color:  #008000;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow8_col8 {
#             background-color:  #0f880f;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow8_col9 {
#             background-color:  #038103;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow9_col6 {
#             background-color:  #008000;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow9_col7 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow9_col8 {
#             background-color:  #56af56;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow9_col9 {
#             background-color:  #4fac4f;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow10_col6 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow10_col7 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow10_col8 {
#             background-color:  #319b31;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow10_col9 {
#             background-color:  #2f9a2f;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow11_col5 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow11_col6 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow11_col7 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow11_col8 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow11_col9 {
#             background-color:  #dcfadc;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow12_col5 {
#             background-color:  #dffcdf;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow12_col6 {
#             background-color:  #dbf9db;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow12_col7 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow12_col8 {
#             background-color:  #d6f7d6;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow12_col9 {
#             background-color:  #e5ffe5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow13_col5 {
#             background-color:  #9ad59a;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow13_col6 {
#             background-color:  #c6eec6;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow13_col7 {
#             background-color:  #b5e4b5;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow13_col8 {
#             background-color:  #abdfab;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow13_col9 {
#             background-color:  #c2ebc2;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow14_col5 {
#             background-color:  #c4edc4;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow14_col6 {
#             background-color:  #c9efc9;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow14_col7 {
#             background-color:  #97d497;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow14_col8 {
#             background-color:  #83c983;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow14_col9 {
#             background-color:  #a6dca6;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4crow15_col5 {
#             background-color:  #94d294;
#         }    #T_060bea7a_0cba_11e9_8c5a_d4bed94dff4cr

# %%
# checking counts by age and AreYouDS and country and gender to get a sense for amount of respondents in each cell
# for "definitily" DS only (AreYouDS=2):

df_top_countries_noNaNs \
    .loc[((df_top_countries_noNaNs.Gender == 'Female') | (df_top_countries_noNaNs.Gender == 'Male'))
           & (df_top_countries_noNaNs.Country != 'China')
           & (df_top_countries_noNaNs.AreYouDS == 2)] \
    .pivot_table(values='Pay', 
                 index=['AreYouDS', 'Age'],
                 columns=['Country','Gender'], 
                 aggfunc=['count', np.mean],
                 margins=True) \
    .style.background_gradient(axis='rows', subset=['mean'], cmap=sns.light_palette("green", as_cmap=True)) \
    .format("{:,.0f}")
# Out:
# <style  type="text/css" >
#     #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow0_col9 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow1_col5 {
#             background-color:  #5ab25a;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow1_col6 {
#             background-color:  #bfeabf;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow1_col7 {
#             background-color:  #96d396;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow1_col8 {
#             background-color:  #b8e6b8;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow1_col9 {
#             background-color:  #c2ebc2;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow2_col5 {
#             background-color:  #b0e1b0;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow2_col6 {
#             background-color:  #c2ecc2;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow2_col7 {
#             background-color:  #66b866;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow2_col8 {
#             background-color:  #8cce8c;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow2_col9 {
#             background-color:  #a6dca6;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow3_col5 {
#             background-color:  #50ac50;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow3_col6 {
#             background-color:  #94d294;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow3_col7 {
#             background-color:  #53ae53;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow3_col8 {
#             background-color:  #68ba68;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow3_col9 {
#             background-color:  #7ec67e;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow4_col6 {
#             background-color:  #7bc47b;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow4_col7 {
#             background-color:  #44a544;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow4_col8 {
#             background-color:  #5db35d;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow4_col9 {
#             background-color:  #6fbd6f;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow5_col5 {
#             background-color:  #e1fde1;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow5_col6 {
#             background-color:  #b5e4b5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow5_col7 {
#             background-color:  #309a30;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow5_col8 {
#             background-color:  #379e37;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow5_col9 {
#             background-color:  #5cb35c;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow6_col5 {
#             background-color:  #008000;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow6_col6 {
#             background-color:  #008000;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow6_col7 {
#             background-color:  #2f9a2f;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow6_col8 {
#             background-color:  #0a850a;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow6_col9 {
#             background-color:  #269526;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow7_col5 {
#             background-color:  #d0f3d0;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow7_col6 {
#             background-color:  #7ac47a;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow7_col7 {
#             background-color:  #008000;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow7_col8 {
#             background-color:  #3aa03a;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow7_col9 {
#             background-color:  #5eb45e;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow8_col5 {
#             background-color:  #ade0ad;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow8_col6 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow8_col7 {
#             background-color:  #339c33;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow8_col8 {
#             background-color:  #3fa33f;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow8_col9 {
#             background-color:  #43a543;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow9_col6 {
#             background-color:  #bae7ba;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow9_col7 {
#             background-color:  #219221;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow9_col8 {
#             background-color:  #2a972a;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow9_col9 {
#             background-color:  #3ba13b;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow10_col6 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow10_col7 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow10_col8 {
#             background-color:  #008000;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow10_col9 {
#             background-color:  #008000;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow11_col5 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow11_col6 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow11_col7 {
#             background-color:  #e5ffe5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow11_col8 {
#             background-color:  #a2daa2;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow11_col9 {
#             background-color:  #91d091;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow12_col5 {
#             background-color:  #8bcd8b;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow12_col6 {
#             background-color:  #b5e4b5;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow12_col7 {
#             background-color:  #59b159;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow12_col8 {
#             background-color:  #6abb6a;
#         }    #T_4028060c_0cbb_11e9_adbc_d4bed94dff4crow12_col9 {
#             background-color:  #8fcf8f;
#         }</style>
# <table id="T_4028060c_0cbb_11e9_adbc_d4bed94dff4c" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" colspan=5>count</th>
#         <th class="col_heading level0 col5" colspan=5>mean</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Country</th>
#         <th class="col_heading level1 col0" colspan=2>India</th>
#         <th class="col_heading level1 col2" colspan=2>United States of America</th>
#         <th class="col_heading level1 col4" >All</th>
#         <th class="col_heading level1 col5" colspan=2>India</th>
#         <th class="col_heading level1 col7" colspan=2>United States of America</th>
#         <th class="col_heading level1 col9" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level2" >Gender</th>
#         <th class="col_heading level2 col0" >Female</th>
#         <th class="col_heading level2 col1" >Male</th>
#         <th class="col_heading level2 col2" >Female</th>
#         <th class="col_heading level2 col3" >Male</th>
#         <th class="col_heading level2 col4" ></th>

# %%
df_for_plot = df_top_countries_noNaNs.loc[((df_top_countries_noNaNs.Gender == 'Female') | (df_top_countries_noNaNs.Gender == 'Male'))
                                   & (df_top_countries_noNaNs.Country == 'India'),
                                ['Age', 'AreYouDS', 'Pay', 'Country', 'Gender']]

g = sns.PairGrid(df_for_plot, hue='Gender')
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_upper(sns.regplot)
g = g.map_lower(sns.kdeplot, shade=True, n_levels=10, shade_lowest=False)
plt.show()

# %%
df_for_plot = df_top_countries_noNaNs.loc[((df_top_countries_noNaNs.Gender == 'Female') | (df_top_countries_noNaNs.Gender == 'Male'))
                                           & (df_top_countries_noNaNs.Country == 'India')
                                           & (df_top_countries_noNaNs.AreYouDS == 2),
                                ['Age', 'AreYouDS', 'Pay', 'Country', 'Gender']]

sns.regplot(df_for_plot[('Age')], df_for_plot[('Pay')], x_jitter=5, y_jitter=0)
sns.kdeplot(df_for_plot[('Age')], df_for_plot[('Pay')], shade=True, n_levels=30, shade_lowest=False)
plt.ylim(0,50000)
plt.show()

# %%
def kde_plotter(df, country, min_level_AreYouDS, addl_title, ax):
    '''
    plots an overlay of two contour plots - blue lines for men and orange contours for women
    
    inputs:
        df - dataframe with data
        country - country name
        min_level_AreYouDS - minimum level for Are you Data Scientist question (-2 = no, +2 = definitely yes)
        addl_title - extra text that will be shown in the title
        ax - axis object for plot
    '''
    
    df_for_plot_male = df.loc[(df.Gender == 'Male')
                               & (df.Country == country)
                               & (df.AreYouDS >= min_level_AreYouDS),
                                    ['Age', 'Pay']]

    df_for_plot_female = df.loc[(df.Gender == 'Female')
                               & (df.Country == country)
                               & (df.AreYouDS >= min_level_AreYouDS),
                                     ['Age', 'Pay']]

    # outline plot for women in blue
    sns.kdeplot(df_for_plot_female[('Age')], df_for_plot_female[('Pay')],
                shade=False, n_levels=15, cmap='Blues', ax=ax)
    
    # filled contours in orange for men
    sns.kdeplot(df_for_plot_male[('Age')], df_for_plot_male[('Pay')],
                shade=True, n_levels=15, shade_lowest=False, cmap='Oranges', ax=ax)
    ax.set_title(country + ' - ' + addl_title)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(16,16))
fig.suptitle('Gender Pay Gap by Country and Experience Level - Women: Blue Contour Lines, Men: Orange Filled Contours')

kde_plotter(df_top_countries_noNaNs, 'United States of America', 1, 'probably or definitely Data Scientist', ax1)    
ax1.set_xlim(10,60)
ax1.set_ylim(0,250000)

kde_plotter(df_top_countries_noNaNs, 'India', 1, 'probably or definitely Data Scientist', ax2)    
ax2.set_xlim(10,40)
ax2.set_ylim(0,50000)

kde_plotter(df_top_countries_noNaNs, 'United States of America', 2, 'definitely Data Scientist', ax3)    
ax3.set_xlim(10,60)
ax3.set_ylim(0,250000)

kde_plotter(df_top_countries_noNaNs, 'India', 2, 'definitely Data Scientist', ax4)
ax4.set_xlim(10,40)
ax4.set_ylim(0,50000)

fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('images\img-USandIndia-dataScientist-pay-by-age-and-level-split.jpg')
plt.show()
